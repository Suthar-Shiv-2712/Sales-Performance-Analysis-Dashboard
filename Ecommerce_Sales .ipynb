# %%
import pandas as pd

# %%
df=pd.read_csv("Ecommerce.csv")
df.head()
# Out:
#    Order_ID  Order_Date Customer_ID   Customer_Name  Gender  Age      City  \
# 0      1127  13-02-2025        C489     Angel Kirby    Male   54    Kanpur
# 1      1162  14-02-2025        C314   Virginia Kirk  Female   37    Jaipur
# 2      1089  17-02-2025        C296  James Gonzalez    Male   26  Vadodara
# 3      1148  17-02-2025        C135   Danielle Pugh    Male   27    Kanpur
# 4      1032  24-02-2025        C462   Suzanne Duran  Female   55   Lucknow
#
#            State Product_Category      Product_Name  Quantity  Price_Per_Unit  \
# 0  Uttar Pradesh          Grocery         Sugar 1kg         3             452
# 1      Rajasthan      Electronics        Power Bank         1             725
# 2        Gujarat      Electronics        Headphones         4            2309
# 3  Uttar Pradesh          Grocery  Basmati Rice 5kg         1            1134
# 4  Uttar Pradesh      Electronics        Headphones         5            4151
#
#    Total_Amount Payment_Mode Order_Status
# 0          1356          COD    Delivered
# 1           725          COD     Returned
# 2          9236          COD     Returned
# 3          1134         Card    Cancelled
# 4         20755         Card    Delivered

# %%
df.isnull().sum()
# Out:
# Order_ID            0
# Order_Date          0
# Customer_ID         0
# Customer_Name       0
# Gender              0
# Age                 0
# City                0
# State               0
# Product_Category    0
# Product_Name        0
# Quantity            0
# Price_Per_Unit      0
# Total_Amount        0
# Payment_Mode        0
# Order_Status        0
# dtype: int64

# %%
# This is Total Sales

# %%
total_sales = df['Price_Per_Unit'].sum()
print("Total Sales:", total_sales)
# Out:
# Total Sales: 504343

# %%
total_revenue = df['Total_Amount'].sum()
print("Total_Revenue:", total_revenue)
# Out:
# Total_Revenue: 1486514

# %%
df.groupby('Product_Category')['Price_Per_Unit'].sum()
# Out:
# Product_Category
# Clothing       159870
# Electronics    201055
# Grocery        143418
# Name: Price_Per_Unit, dtype: int64

# %%
df.to_csv('Ecommerce.csv',index=False)
